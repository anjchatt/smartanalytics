# %%
import sys
import time
from pyspark import SparkContext
from pyspark.streaming import StreamingContext

# %%
import pandas as pd
import pickle
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %%
import pickle
with open("data/learned_rft_NBA_model.pkl","rb") as f:
  rfc = pickle.load(f)

# %%
# There already exists 'sc' as SparkContext
#sc = SparkContext("local", appName="CalculateNBA")
ssc = StreamingContext(sc, 1)

# %%
 #sqlc = pyspark.sql.SQLContext(sc)

# %%
# read some data
data = pd.read_csv("data/merged_dataset_python.csv", nrows=10000)
data.shape
# Out:
# (10000, 94)

# %%
# Exclude all fields except mentioned here
usefields = ["is_maried", "age", "work_experience", "children_number", "has_mortgage",
            "loan_products_nii", "checking_account_balance", "deposit_balance", "money_market_balance",
            "investable_asset_indicator", "Sentiment", "Sentiment_days_passed",
            "NBO_choosen"]
data = data[usefields]
data["is_maried"] = data["is_maried"].astype(int)
#save ID for future references 
data["id"]=data.index+1
data.shape
# Out:
# (10000, 14)

# %%
rddQueue = []
for i in range(0, len(data), 100):
    #rddQueue += [ssc.sparkContext.parallelize([j for j in range(1, 1001)], 10)]
    rddQueue += [sqlContext.createDataFrame(data[i:i+100]).rdd]
#ssc.sparkContext.parallelize(rddQueue, 2)
len(rddQueue)
# Out:
# 100

# %%
def predict(row):
    ordered_list = []
    for i in ["is_maried", "age", "work_experience", "children_number", "has_mortgage",
                "loan_products_nii", "checking_account_balance", "deposit_balance", "money_market_balance",
                "investable_asset_indicator", "Sentiment", "Sentiment_days_passed"]:
        ordered_list.append(row[i])
    res = rfc.predict_proba(np.array(ordered_list).reshape(1,-1))
    return np.append(res, row["id"])
    #return (row["id"], res)

# %%
# Create the QueueInputDStream and use it do some processing
inputStream = ssc.queueStream(rddQueue)

# %%
mappedStream = inputStream.map(lambda x: predict(x))
#reducedStream = mappedStream.reduceByKey(lambda a, b: a + b)
#reducedStream.pprint()
mappedStream.pprint()
#mappedStream.saveAsTextFiles("hdfs:///tmp/prediction.txt")
ssc.start()
time.sleep(10)
# Out:
# -------------------------------------------
# Time: 2016-03-11 10:48:33
# -------------------------------------------
# [ 0.  1.  0.  0.  0.  1.]
# [ 1.  0.  0.  0.  0.  2.]
# [ 0.          0.52380952  0.47619048  0.          0.          3.        ]
# [ 0.14285714  0.42857143  0.          0.42857143  0.          4.        ]
# [ 0.          0.95238095  0.          0.          0.04761905  5.        ]
# [ 0.          0.04761905  0.85714286  0.0952381   0.          6.        ]
# [ 0.19047619  0.52380952  0.04761905  0.04761905  0.19047619  7.        ]
# [ 0.          0.95238095  0.          0.04761905  0.          8.        ]
# [ 0.          0.42857143  0.14285714  0.38095238  0.04761905  9.        ]
# [  0.04761905   0.23809524   0.04761905   0.52380952   0.14285714  10.        ]
# ...
#
# -------------------------------------------
# Time: 2016-03-11 10:48
   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   6.10000000e+02]
# ...
#
# -------------------------------------------
# Time: 2016-03-11 10:48:40
# -------------------------------------------
# [  2.38095238e-01   7.14285714e-01   4.76190476e-02   0.00000000e+00
#    0.00000000e+00   7.01000000e+02]
# [  9.52380952e-01   0.00000000e+00   4.76190476e-02   0.00000000e+00
#    0.00000000e+00   7.02000000e+02]
# [  0.00000000e+00   4.76190476e-02   9.52380952e-01   0.00000000e+00
#    0.00000000e+00   7.03000000e+02]
# [  0.00000000e+00   9.04761905e-01   0.00000000e+00   4.76190476e-02
#    4.76190476e-02   7.04000000e+02]
# [  9.52380952e-02   2.85714286e-01   5.71428571e-01   0.00000000e+00
#    4.76190476e-02   7.05000000e+02]
# [  0.00000000e+00   4.76190476e-02   9.04761905e-01   4.76190476e-02
#    0.00000000e+00   7.06000000e+02]
# [  0.00000000e+00   8.09523810e-01   4.76190476e-02   1.42857143e-01
#    0.00000000e+00   7.07000000e+02]
# [   0.    0.    0.    1.    0.  708.]
# [   1.    0.    0.    0.    0.  709.]
# [  0.00000000e+00   9.04761905e-01   0.00000000e+00   9.52380952e-02
#    0.00000000e+00   7.10000000e+02]
# ...
#
# -------------------------------------------
# Time: 2016-03-11 10:48:41
# -------------------------------------------
# [  9.04761905e-01   9.52380952e-02   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   8.01000000e+02]
# [  1.42857143e-01   4.76190476e-02   0.00000000e+00   4.28571429e-01
#    3.80952381e-01   8.02000000e+02]
# [  0.00000000e+00   4.76190476e-02   8.57142857e-01   9.52380952e-02
#    0.00000000e+00   8.03000000e+02]
# [  4.76190476e-02   0.00000000e+00   0.00000000e+00   4.76190476e-02
#    9.04761905e-01   8.04000000e+02]
# [  2.38095238e-01   5.71428571e-01   0.00000000e+00   4.76190476e-02
#    1.42857143e-01   8.05000000e+02]
# [   1.    0.    0.    0.    0.  806.]
# [  0.00000000e+00   9.52380952e-02   8.57142857e-01   4.76190476e-02
#    0.00000000e+00   8.07000000e+02]
# [   1.    0.    0.    0.    0.  808.]
# [  1.42857143e-01   5.23809524e-01   0.00000000e+00   9.52380952e-02
#    2.38095238e-01   8.09000000e+02]
# [   1.    0.    0.    0.    0.  810.]
# ...

# %%
ssc.stop(stopSparkContext=False, stopGraceFully=True)
# Out:
# -------------------------------------------
# Time: 2016-03-11 10:48:42
# -------------------------------------------
# [  2.85714286e-01   2.85714286e-01   4.76190476e-02   0.00000000e+00
#    3.80952381e-01   9.01000000e+02]
# [  0.00000000e+00   9.52380952e-01   0.00000000e+00   4.76190476e-02
#    0.00000000e+00   9.02000000e+02]
# [  8.57142857e-01   0.00000000e+00   0.00000000e+00   1.42857143e-01
#    0.00000000e+00   9.03000000e+02]
# [  4.76190476e-02   0.00000000e+00   9.52380952e-01   0.00000000e+00
#    0.00000000e+00   9.04000000e+02]
# [   1.    0.    0.    0.    0.  905.]
# [  7.61904762e-01   1.42857143e-01   4.76190476e-02   4.76190476e-02
#    0.00000000e+00   9.06000000e+02]
# [  0.00000000e+00   8.09523810e-01   9.52380952e-02   9.52380952e-02
#    0.00000000e+00   9.07000000e+02]
# [  1.90476190e-01   4.76190476e-02   4.76190476e-01   2.85714286e-01
#    0.00000000e+00   9.08000000e+02]
# [  0.00000000e+00   9.52380952e-01   0.00000000e+00   4.76190476e-02
#    0.00000000e+00   9.09000000e+02]
# [  9.52380952e-01   0.00000000e+00   0.00000000e+00   4.76190476e-02
#    0.00000000e+00   9.10000000e+02]
# ...
#
# -------------------------------------------
# Time: 2016-03-11 10:48:43
# -------------------------------------------
# [  0.00000000e+00   0.00000000e+00   9.52380952e-01   4.76190476e-02
#    0.00000000e+00   1.00100000e+03]
# [  1.90476190e-01   4.76190476e-02   1.42857143e-01   5.71428571e-01
#    4.76190476e-02   1.00200000e+03]
# [  1.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   1.00300000e+03]
# [  0.00000000e+00   0.00000000e+00   0.00000000e+00   1.00000000e+00
#    0.00000000e+00   1.00400000e+03]
# [  0.00000000e+00   1.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   1.00500000e+03]
# [  4.76190476e-02   0.00000000e+00   2.38095238e-01   7.14285714e-01
#    0.00000000e+00   1.00600000e+03]
# [  6.19047619e-01   2.38095238e-01   9.52380952e-02   4.76190476e-02
#    0.00000000e+00   1.00700000e+03]
# [  1.90476190e-01   2.38095238e-01   1.42857143e-01   3.80952381e-01
#    4.76190476e-02   1.00800000e+03]
# [  1.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   1.00900000e+03]
# [  9.04761905e-01   4.76190476e-02   4.76190476e-02   0.00000000e+00
#    0.00000000e+00   1.01000000e+03]
# ...
#
# -------------------------------------------
# Time: 2016-03-11 10:48:44
# -------------------------------------------
# [  0.00000000e+00   7.61904762e-01   0.00000000e+00   2.38095238e-01
#    0.00000000e+00   1.10100000e+03]
# [  5.71428571e-01   4.76190476e-02   9.52380952e-02   0.00000000e+00
#    2.85714286e-01   1.10200000e+03]
# [  4.76190476e-02   9.52380952e-02   8.57142857e-01   0.00000000e+00
#    0.00000000e+00   1.10300000e+03]
# [  0.00000000e+00   2.85714286e-01   6.66666667e-01   4.76190476e-02
#    0.00000000e+00   1.10400000e+03]
# [  0.00000000e+00   2.38095238e-01   5.71428571e-01   1.90476190e-01
#    0.00000000e+00   1.10500000e+03]
# [  7.61904762e-01   1.90476190e-01   4.76190476e-02   0.00000000e+00
#    0.00000000e+00   1.10600000e+03]
# [  4.76190476e-02   4.76190476e-02   4.76190476e-02   1.90476190e-01
#    6.66666667e-01   1.10700000e+03]
# [  0.00000000e+00   4.76190476e-02   9.52380952e-01   0.00000000e+00
#    0.00000000e+00   1.10800000e+03]
# [  0.00000000e+00   0.00000000e+00   1.00000000e+00   0.00000000e+00
#    0.00000000e+00   1.10900000e+03]
# [  0.00000000e+00   0.00000000e+00   1.00000000e+00   0.00000000e+00
#    0.00000000e+00   1.11000000e+03]
# ...
